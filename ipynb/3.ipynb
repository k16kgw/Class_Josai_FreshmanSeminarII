# %%
score = 85
if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
else:
    print("D")
# Out:
# B

# %%
s = input("整数を入力: ")# inputでキーボードからの入力値を変数に代入する
try:
    n = int(s)
    if n % 2 == 0:
        print("偶数")
    else:
        print("奇数")
except ValueError:
    print("整数を入力してください")
# Out:
# 偶数

# %%
year = 2100
if (year%4==0 and year%100!=0) or year%400==0:
    print("うるう年")
else:
    print("平年")
# Out:
# 平年
